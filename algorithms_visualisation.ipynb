# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,3, figsize = (10,5))
for i,name in enumerate(images_cakes):
    img = Image.open(name)
    cropped_img=img.crop((900,900,950,950)) #(400,400,500,500)
    ax[i].imshow(cropped_img)
    ax[i].axis('off')
    ax[i].set_title(name)

# %%
img.size
# Out:
# (1440, 1440)

# %%
from skimage import io

# %%
img = io.imread("wool_bicubic.png")
io.imshow(img)
;
# Out:
# ''
